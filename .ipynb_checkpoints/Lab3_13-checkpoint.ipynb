# %%
import numpy as np
import pandas as pd
import seaborn as sns
import networkx as nx
import matplotlib.pyplot as plt
from scipy.stats import zscore
from scipy.spatial.distance import pdist, squareform
from sklearn.cluster import KMeans, SpectralClustering, AgglomerativeClustering
from sklearn.mixture import GaussianMixture as GM
from sklearn.metrics import rand_score, silhouette_score
import matplotlib.cm as cm
import community as community_louvain

# %%
np.set_printoptions(suppress=True)

# %% [markdown]
# <h2>0.1. Предварительная обработка данных</h2>

# %%
X = pd.read_excel('X_4_13.xlsx', header=None)

Y = pd.read_excel('Y_4_13.xlsx', header=None)

X
# Out:
#             0         1         2         3
# 0    5.092168  1.034724  7.080165 -1.987996
# 1    4.846424  0.968371  6.787735 -1.941311
# 2    5.297292  1.205368  6.978480 -1.681188
# 3    3.729736  0.846779  4.919136 -1.189400
# 4    5.003340  1.094723  6.722511 -1.719171
# ..        ...       ...       ...       ...
# 195  3.674291  0.826147  4.870143 -1.195852
# 196  3.711996  0.911068  4.690788 -0.978792
# 197  4.504129  0.705877  6.890626 -2.386497
# 198  4.891603  0.973449  6.862858 -1.971255
# 199  4.611003  0.734562  7.018320 -2.407317
#
# [200 rows x 4 columns]

# %%
X.describe()
# Out:
#                 0           1           2           3
# count  200.000000  200.000000  200.000000  200.000000
# mean     2.999880    0.978973    3.062841   -0.062961
# std      2.665400    1.190919    2.636290    1.659201
# min     -1.770611   -1.098890   -1.686545   -3.001601
# 25%      0.967169    0.094967    1.037855   -1.337723
# 50%      3.043348    1.013192    3.001980   -0.003096
# 75%      5.053307    1.939336    5.064147    1.147939
# max      7.684823    3.085918    8.097899    3.110166

# %%
X.isnull().sum()
# Out:
# 0    0
# 1    0
# 2    0
# 3    0
# dtype: int64

# %%
plt.figure(figsize=(10,4))
sns.boxplot(data=X, orient='h')
# Out:
# <AxesSubplot:>

# %%
Y
# Out:
#             0         1         2         3
# 0    0.906940  1.006914  0.963778  0.824834
# 1    2.029085  0.799312  1.623610  0.952911
# 2    1.978421  1.102946  1.458704  0.978444
# 3    2.275134  0.829438  1.964464  1.040498
# 4    1.276684  0.056152 -0.198731  1.130742
# ..        ...       ...       ...       ...
# 195  2.011200  0.939179  1.924253  0.916095
# 196  2.166127  1.092028  1.849896  1.069608
# 197  1.004772  0.952281  0.960462  0.711798
# 198  1.894961  0.872430  1.811809  1.079972
# 199  1.964912  1.133258  2.427070  0.993946
#
# [200 rows x 4 columns]

# %%
Y.isnull().sum()
# Out:
# 0    0
# 1    0
# 2    0
# 3    0
# dtype: int64

# %%
plt.figure(figsize=(15,5))
sns.boxplot(data=Y, orient='h')
# Out:
# <AxesSubplot:>

# %% [markdown]
# Стандартизируем данные, используя z-оценку:

# %%
X_st = pd.DataFrame(zscore(X))
Y_st = pd.DataFrame(zscore(Y))

# %% [markdown]
# Чтобы сделать предварительные выводы о количестве и видах кластеров, а также выбрать подходящий алгоритм кластеризации, визуализируем данные, предварительно уменьшив их размерность до n=2. Чтобы понять, насколько будет велика погрешность в этом случае, выполним SVD-разложение и рассчитаем ошибку аппроксимации:

# %%
def count_approx_error(S):
    ev_table = pd.DataFrame()

    pc_num = [i+1 for i in range(len(S))]
    
    ev_table[0] = pc_num
    
    ev_table[1] = S.round(2)
    
    qrS = S ** 2
    
    ev_table[2] = qrS.round(2)
   
    percentvar = [round(i/sum(qrS)*100,2) for i in S**2]
    
    ev_table[3] = percentvar
    
    ev_table[4] = np.cumsum(percentvar)

    ev_table.columns=['Главные факторы', 'Сингулярные значения',
                                    'Собственные значения', 'Вклад в вариацию(%)',
                                    'Кумулятивный вклад в вариацию(%)']
    return ev_table

# %%
Ux, Sx, VTx = np.linalg.svd(X_st)
count_approx_error(Sx)
# Out:
#    Главные факторы  Сингулярные значения  Собственные значения  \
# 0                1                 22.83                521.26
# 1                2                 16.70                278.74
# 2                3                  0.00                  0.00
# 3                4                  0.00                  0.00
#
#    Вклад в вариацию(%)  Кумулятивный вклад в вариацию(%)
# 0                65.16                             65.16
# 1                34.84                            100.00
# 2                 0.00                            100.00
# 3                 0.00                            100.00

# %%
Uy, Sy, VTy = np.linalg.svd(Y_st)
count_approx_error(Sy)
# Out:
#    Главные факторы  Сингулярные значения  Собственные значения  \
# 0                1                 22.11                488.90
# 1                2                 14.20                201.64
# 2                3                  9.92                 98.34
# 3                4                  3.33                 11.12
#
#    Вклад в вариацию(%)  Кумулятивный вклад в вариацию(%)
# 0                61.11                             61.11
# 1                25.20                             86.31
# 2                12.29                             98.60
# 3                 1.39                             99.99

# %% [markdown]
# В случае с датасетом X первые 2 признака сохраняют 100% информации. В случае с датасетом Y при n = 2 ошибка  составляет 13.69%, что достаточно мало для того, чтобы ориентироваться на такую аппроксимацию.
#
# Теперь визуализируем данные: построим карты объектов для X и для Y.

# %%
X_2d = Ux[:,:2]
plt.plot(X_2d[:,0], X_2d[:,1],'bo')

# %%
Y_2d = Uy[:,:2]
plt.plot(Y_2d[:,0], Y_2d[:,1],'bo')

# %% [markdown]
# В датасете Y мы видим 3 четко сформированных кластера примерно одинакового размера, для каждого из которых можно найти центр. Предположительно любой алгоритм, использующий центры кластеров, даст соответствующий результат.
#
# Датасет X представляет собой 2 концентрических кластера, не имеющих центра. Вероятно, стандартные алгоритмы не смогут выполнить кластеризацию правильным образом.

# %% [markdown]
# <h2>0.2. Подготовка данных</h2>

# %%
from sklearn.manifold import MDS

# %%
metrics = ('mahalanobis', 'correlation', 'minkowski', 'euclidean')

dist_m_x = {}

dist_m_y = {}

for metric in metrics:
    
    dist_m_x[metric] = pdist(X_st, metric, p=1)
    
    dist_m_y[metric] = pdist(Y_st, metric, p=1)
    
dist_m_x = pd.DataFrame(dist_m_x)
dist_m_y = pd.DataFrame(dist_m_y)

# %% [markdown]
# Корреляции между расстояниями:

# %%
dist_m_x.corr('kendall')
# Out:
#              mahalanobis  correlation  minkowski  euclidean
# mahalanobis     1.000000     0.539039   0.779450   0.813653
# correlation     0.539039     1.000000   0.431137   0.460070
# minkowski       0.779450     0.431137   1.000000   0.947866
# euclidean       0.813653     0.460070   0.947866   1.000000

# %%
dist_m_y.corr('kendall')
# Out:
#              mahalanobis  correlation  minkowski  euclidean
# mahalanobis     1.000000     0.388785   0.538976   0.577128
# correlation     0.388785     1.000000   0.426155   0.434227
# minkowski       0.538976     0.426155   1.000000   0.889614
# euclidean       0.577128     0.434227   0.889614   1.000000

# %% [markdown]
# Выберем расстояние следующим образом: на основе матрицы расстояний проведем многомерное шкалирование и визуализируем результаты. Мы предполагаем, что метрика расстояния подойдет для решения данной задачи, если полученные на ее основе 2-мерные векторы образуют то же количество кластеров с примерно тем же количеством элементов в каждом из них.

# %%
def perform_mds(dist_m):
    
    for distance_matrix in dist_m:
        
        print('Метрика: {}'.format(distance_matrix))
        
        tmp_new = embedding.fit_transform(squareform(dist_m[distance_matrix]))
        
        plt.plot(tmp_new[:,0], tmp_new[:,1],'bo')
        
        plt.show()

# %% [markdown]
# MDS для датасета X:

# %%
embedding = MDS(n_components=2, dissimilarity = 'precomputed', eps=1e-6)

perform_mds(dist_m_x)
# Out:
# Метрика: mahalanobis
# Метрика: correlation
# Метрика: minkowski
# Метрика: euclidean

# %% [markdown]
# Датасет Y:

# %%
perform_mds(dist_m_y)
# Out:
# Метрика: mahalanobis
# Метрика: correlation
# Метрика: minkowski
# Метрика: euclidean

# %% [markdown]
# Видно, что структура кластеров сохраняется для всех расстояний, кроме корреляции, но точнее всего повторяют карту объектов векторы, полученные на основе евклидова расстояния. Его и будем использовать для кластеризации.
#
# Получим матрицу близости на основе матрицы расстояний и построим графовую модель для каждого датасета:

# %%
def similarity_to_graph(sim_mat):
    n = sim_mat.shape[0]
    G = nx.Graph()
    _ = [G.add_node(i for i in range(n))]
    for i in range(len(sim_mat)-1):
        for j in range(i+1,len(sim_mat)):
            w = sim_mat[i][j]
            G.add_edge(i, j, weight=w)
        
    G.remove_node(list(G.nodes)[0])
    return G

# %%
X_dis = squareform(pdist(X_st, 'euclidean'))
similarity_X = np.exp(-X_dis**2*6)
X_graph = similarity_to_graph(similarity_X)

# %%
Y_dis = squareform(pdist(Y_st, 'euclidean'))
similarity_Y = np.exp(-Y_dis**2*1/4)
Y_graph = similarity_to_graph(similarity_Y)

# %% [markdown]
# ## Кластеризация

# %% [markdown]
# ### 1. Кластеризация для числа кластеров k=2.

# %%
def perform_clustering(sim_matrix, dataset, n = 2):

    clusters = {}

    #single linkage
    
    clusters['single linkage'] = AgglomerativeClustering(n_clusters=n, 
                                                         linkage='single').fit_predict(sim_matrix)
    
    #EM-algo
    
    em = GM(n_components=n, covariance_type='full',  tol = 1e-06)
    
    clusters['EM-algorithm'] = em.fit_predict(dataset)
    
    #k-means 
    
    clusters['k-means'] = KMeans(n_clusters=n, random_state=32).fit_predict(dataset)
    
    #spectral
    
    clusters['spectral'] = SpectralClustering(n_clusters=n,
                                affinity ='precomputed',
                                random_state=32).fit_predict(sim_matrix)
    
    return pd.DataFrame(clusters)

def get_rindex_matrix(clusters, num_of_algos = 4):
    
    """Возвращает матрицу RAND индексов для каждой пары делений на кластеры
    clusters - pd. DataFrame - кластеры, полученные разными алгоритмами
    num_of_algos - количество примененных алгоритмов"""
    
    rand_index = lambda i,j: rand_score(clusters[clusters.columns[i]], clusters[clusters.columns[j]])
    
    rand_X = np.array([rand_index(i,j) for i in range(num_of_algos) for j in range(num_of_algos)]).reshape(4,4)

    return pd.DataFrame(rand_X, index = clusters_X.columns, columns = clusters_X.columns)

# %%
clusters_X = perform_clustering(similarity_X, X_st)
clusters_Y = perform_clustering(similarity_Y, Y_st)

# %% [markdown]
# ### K-means

# %%
color_map = ['darkred', 'steelblue', 'darkseagreen']
def plot_clusters(algo, clst):
    
    data = X_2d if clst == 'X' else Y_2d
    
    clusters = clusters_X if clst == 'X' else clusters_Y
    
    for i in range(200):
        
        plt.scatter(data[:,0][i] , data[:,1][i], color=color_map[clusters[algo][i]])

# %%
plot_clusters('k-means', 'X')

# %%
plot_clusters('k-means', "Y")

# %% [markdown]
# ### Spectral Clustering

# %%
plot_clusters('spectral', "X")

# %%
plot_clusters('spectral', "Y")

# %% [markdown]
# ### EM-algorithm

# %%
plot_clusters('EM-algorithm', "X")

# %%
plot_clusters('EM-algorithm', "Y")

# %% [markdown]
# ### Single linkage

# %%
plot_clusters('single linkage', "X")

# %%
plot_clusters('single linkage', "Y")

# %% [markdown]
# ### Оценка по RAND

# %%
rindex_X = get_rindex_matrix(clusters_X)
rindex_X
# Out:
#                 single linkage  EM-algorithm   k-means  spectral
# single linkage        1.000000      0.500704  0.497688  1.000000
# EM-algorithm          0.500704      1.000000  0.772663  0.500704
# k-means               0.497688      0.772663  1.000000  0.497688
# spectral              1.000000      0.500704  0.497688  1.000000

# %% [markdown]
# Для датасета X Single Linkage и Spectral Clustering, как можно убедиться из графиков, дают одинаковые результаты. K-means и EM не учитывают концентрическую форму кластера, разделяя окружности предполагаемых кластеров пополам - отсюда такие оценки при оценивании по RAND (EM и K-means почти близки (rand index~0.77)

# %%
rindex_Y = get_rindex_matrix(clusters_Y)
rindex_Y
# Out:
#                 single linkage  EM-algorithm   k-means  spectral
# single linkage        1.000000      1.000000  1.000000  0.586131
# EM-algorithm          1.000000      1.000000  1.000000  0.586131
# k-means               1.000000      1.000000  1.000000  0.586131
# spectral              0.586131      0.586131  0.586131  1.000000

# %% [markdown]
# Датасет Y, для которого мы предположили наиболее оптимальной разбиение на 3 кластера, при поиске 2 кластеров ожидаемо дает неверные результаты. Работа алгоритмов в этом случае практически идентична: два гипотетических отдельных кластера объединяются. Однако спектральная кластеризация разделяет кластеры немного иначе.

# %% [markdown]
# ### Оценка модулярности

# %%
def get_modularity_for_2(G, clusters):
    cluster1 = []
    cluster2 = []
    cluster_labels = np.array(clusters).tolist()
    for id, e in enumerate(cluster_labels):
        if e == 0:
            cluster1.append(id)
        else:
            cluster2.append(id)
    similarity_communities = [set(cluster1), set(cluster2)]
    modularity = nx.algorithms.community.quality.modularity(G, similarity_communities)
    return modularity

def print_modularity_2():
    print("Модулярность для набора данных X:")
    print("single linkage:", get_modularity_for_2(X_graph, clusters_X['single linkage']))
    print("EM-algorithm:", get_modularity_for_2(X_graph, clusters_X['EM-algorithm']))
    print("k-means:", get_modularity_for_2(X_graph, clusters_X['k-means']))
    print("spectral:", get_modularity_for_2(X_graph, clusters_X['spectral']))
    print()
    print("Модулярность для набора данных Y:")
    print("single linkage:", get_modularity_for_2(Y_graph, clusters_Y['single linkage']))
    print("EM-algorithm:", get_modularity_for_2(Y_graph, clusters_Y['EM-algorithm']))
    print("k-means:", get_modularity_for_2(Y_graph, clusters_Y['k-means']))
    print("spectral:", get_modularity_for_2(Y_graph, clusters_Y['spectral']))

# %%
print_modularity_2()
# Out:
# Модулярность для набора данных X:
# single linkage: 0.4976842422371437
# EM-algorithm: 0.4615018157466498
# k-means: 0.4481713663753224
# spectral: 0.4976842422371437
#
# Модулярность для набора данных Y:
# single linkage: 0.3303633763555988
# EM-algorithm: 0.2808946652560481
# k-means: 0.3303633763555988
# spectral: 0.2808946652560481

# %% [markdown]
# В случае с набором данных X функция модулярности принимает наибольшие значения для кластеров, полученных с помощью single linkage и spectral clustering, что согласуется с визуальным делением на кластеры. Однако улучшение модулярности по сравнению с другими алгоритмами незначительно. Это можно объяснить формой кластеров: часть объектов из датасета X, принадлежащих одному кластеру, находятся на большем расстоянии друг от друга, чем от объектов кластера, к которому они не принадлежат (и, соответственно, имеют низкий коэффициент близости). Поскольку в качестве ребер графа мы используем матрицу близости, такие объекты будут интерпретированы функцией модулярности как не принадлежащие одной группе. Поэтому можно сказать, что для данного вида кластеров такая оценка качества, как модуляция, недостаточно надежна.

# %% [markdown]
# **Выводы**
#
# Набор данных X можно разбить на 2 кластера, что подтвержается визуализацией. Спектральная кластеризация и single linkage выделяют два концентрических кластера - внутренний и внешний. EM-алгоритм и k-means делят данные по некоторой средней линии, что для данного датасета не отражает действительного распределения данных по группам.
#
# С делением набора Y на 2 группы все 4 алгоритма справились одинаково, выделив один визуальный кластер и объединив два других в один общий. Однако для этого набора данных деление на 3 кластера не оптимально.

# %% [markdown]
# ### 2. Кластеризация для числа кластеров k=3.

# %%
clusters_X = perform_clustering(similarity_X, X_st, 3)
clusters_Y = perform_clustering(similarity_Y, Y_st, 3)

# %% [markdown]
# ### K-means

# %%
plot_clusters('k-means', 'X')

# %%
plot_clusters('k-means', 'Y')

# %% [markdown]
# ### SpectralClustering

# %%
plot_clusters('spectral', 'X')

# %%
plot_clusters('spectral', 'Y')

# %% [markdown]
# ### EM-algorithm

# %%
plot_clusters('EM-algorithm', "X")

# %%
plot_clusters('EM-algorithm', "Y")

# %% [markdown]
# ### Single linkage

# %%
plot_clusters('single linkage', "X")

# %%
plot_clusters('single linkage', "Y")

# %% [markdown]
# ### Оценка по RAND

# %%
rindex_X = get_rindex_matrix(clusters_X)
rindex_X
# Out:
#                 single linkage  EM-algorithm   k-means  spectral
# single linkage        1.000000      0.557286  0.542412  0.748744
# EM-algorithm          0.557286      1.000000  0.665829  0.599899
# k-means               0.542412      0.665829  1.000000  0.673568
# spectral              0.748744      0.599899  0.673568  1.000000

# %% [markdown]
# Для X алгоритмы дают разные разбиения. Spectral Clustring и Single Linkage алгоритм, как и в случае с двухкластерным разделением, дают достаточно близкие результаты, различие состоит в том, что Single Linkage на два разных кластера разделяет внутренний круг (можно также визуально отметить, что расстояние между этими двумя кластерами наиболее велико), Spectral - разделяет внешний круг. EM алгоритм и K-means придерживаются схожего принципа, разделяя кластеры по долям (каждый занимает приблизительно по 1/3), однако имеют разные результаты.

# %%
rindex_Y = get_rindex_matrix(clusters_Y)
rindex_Y
# Out:
#                 single linkage  EM-algorithm  k-means  spectral
# single linkage             1.0           1.0      1.0       1.0
# EM-algorithm               1.0           1.0      1.0       1.0
# k-means                    1.0           1.0      1.0       1.0
# spectral                   1.0           1.0      1.0       1.0

# %% [markdown]
# Для датасета Y все алгоритмы дали идентичный результат: кластеры можно определить визуально, расстояние между объектами разных кластеров велико, близость - мала.

# %% [markdown]
# ### Оценка модулярности

# %%
def get_modularity_for_3(G, clusters):
    cluster1 = []
    cluster2 = []
    cluster3 = []
    cluster_labels = np.array(clusters).tolist()
    for id, e in enumerate(cluster_labels):
        if e == 0:
            cluster1.append(id)
        elif e == 1:
            cluster2.append(id)
        else:
            cluster3.append(id)
    similarity_communities = [set(cluster1), set(cluster2), set(cluster3)]
    modularity = nx.algorithms.community.quality.modularity(G, similarity_communities)
    return modularity

def print_modularity_3():
    print("Модулярность для набора данных X:")
    print("single linkage:", get_modularity_for_3(X_graph, clusters_X['single linkage']))
    print("EM-algorithm:", get_modularity_for_3(X_graph, clusters_X['EM-algorithm']))
    print("k-means:", get_modularity_for_3(X_graph, clusters_X['k-means']))
    print("spectral:", get_modularity_for_3(X_graph, clusters_X['spectral']))
    print()
    print("Модулярность для набора данных Y:")
    print("single linkage:", get_modularity_for_3(Y_graph, clusters_Y['single linkage']))
    print("EM-algorithm:", get_modularity_for_3(Y_graph, clusters_Y['EM-algorithm']))
    print("k-means:", get_modularity_for_3(Y_graph, clusters_Y['k-means']))
    print("spectral:", get_modularity_for_3(Y_graph, clusters_Y['spectral']))

# %%
print_modularity_3()
# Out:
# Модулярность для набора данных X:
# single linkage: 0.6034210482737821
# EM-algorithm: 0.6162965119322577
# k-means: 0.5956036840839298
# spectral: 0.6111375114821844
#
# Модулярность для набора данных Y:
# single linkage: 0.384918265285757
# EM-algorithm: 0.384918265285757
# k-means: 0.384918265285757
# spectral: 0.384918265285757

# %% [markdown]
# **Выводы**
#
# Набор данных X можно разделить на 3 кластера, но каждый из 4 алгоритмов кластеризации делит данные по-разному. Single linkage выделяет внешний кластер и делит внутренний набор данных на два кластера, а спектральный анализ выделяет внутренний кластер и делит внешний набор данных на два разных кластера. По визуализации мы можем сделать вывод, что такое разбиение не оптимально. Остальные два алгоритма делят данные на три приблизительно равных кластера.
#
# Набор данных Y все 4 способа кластеризации поделили на три кластера одинаково, что также заметно по RAND индексам и по визуализации кластеров. На основе этих результатов мы можем сделать вывод, что разбиение на три класса можно считать оптимальным.

# %% [markdown]
# ### Нахождение оптимального числа кластеров и оценка кластеризации

# %% [markdown]
# ### Silhouette Score

# %% [markdown]
# Для проверки, какое количество кластеров оптимально, используем метрику Silhouette Score. Для этого найдем результаты кластеризации всеми алгоритмами, которые использовались ранее, для разного количества кластеров, от 2 до 10.

# %%
def get_silhouette_score(similarity, data):
    silhouette_coefficients = {}
    for k in range(2, 11):
        clusters = perform_clustering(similarity, data, k)
        score = []
        for i in clusters.columns:
            score.append(silhouette_score(data, list(clusters[i])))
        silhouette_coefficients[k] = score
    silhouette_db = pd.DataFrame(silhouette_coefficients, index=clusters.columns)
    return silhouette_db

# %%
def show_silhouette(score_db):
    plt.plot(score_db.loc['single linkage'], color='steelblue')
    plt.plot(score_db.loc['EM-algorithm'], color='teal')
    plt.plot(score_db.loc['k-means'], color='darkseagreen')
    plt.plot(score_db.loc['spectral'], color='olive')

    plt.xlabel('Число кластеров')
    plt.ylabel('silhouette score')
    plt.legend(['single linkage', 'EM-algorithm', 
                'k-means', 'spectral clustering'])
    plt.show()

# %% [markdown]
# #### Для датасета X

# %%
X_score = get_silhouette_score(similarity_X, X_st)
X_score
# Out:
# c:\users\зоя\appdata\local\programs\python\python38\lib\site-packages\sklearn\mixture\_base.py:277: ConvergenceWarning: Initialization 1 did not converge. Try different init parameters, or increase max_iter, tol or check for degenerate data.
#   warnings.warn(
#                       2         3         4         5         6         7   \
# single linkage  0.066786 -0.028381  0.091952  0.250562  0.276719  0.296685
# EM-algorithm    0.393312  0.365669  0.322373  0.332386  0.259506  0.345813
# k-means         0.411009  0.394254  0.392966  0.384061  0.371958  0.407057
# spectral        0.066786  0.211646  0.278973  0.285374  0.336064  0.337724
#
#                       8         9         10
# single linkage  0.270103  0.340438  0.291433
# EM-algorithm    0.395990  0.395226  0.386667
# k-means         0.442965  0.439957  0.418873
# spectral        0.408266  0.438396  0.439977

# %%
show_silhouette(X_score)

# %% [markdown]
# Для графа X из оценок силуэта видим, что оптимальные значения достигаются при количестве кластеров больше 8.
#
# При двух кластерах, которые мы предварительно определили как оптимальные, оценки силуэта для single linkage и spectral clustering минимальные, хотя они показали лучшее разделение, схожее с нашим изначальным предположением.
#
# По силуэту и модулярности разбиение на три кластера получает оценки выше, чем для двух кластеров.

# %% [markdown]
# #### Для датасета Y
#
# Оценка силуэта уже показывает, что по всем способам кластеризации оптимальные - на 3 кластера

# %%
Y_score = get_silhouette_score(similarity_Y, Y_st)
Y_score
# Out:
# c:\users\зоя\appdata\local\programs\python\python38\lib\site-packages\sklearn\mixture\_base.py:277: ConvergenceWarning: Initialization 1 did not converge. Try different init parameters, or increase max_iter, tol or check for degenerate data.
#   warnings.warn(
#                       2         3         4         5         6         7   \
# single linkage  0.462957  0.520082  0.457260  0.435684  0.375543  0.332111
# EM-algorithm    0.463267  0.520082  0.438512  0.316646  0.269340  0.354531
# k-means         0.462957  0.520082  0.504126  0.438569  0.368323  0.372067
# spectral        0.463267  0.520082  0.508438  0.424785  0.397939  0.378001
#
#                       8         9         10
# single linkage  0.327530  0.341259  0.220261
# EM-algorithm    0.228207  0.253401  0.247965
# k-means         0.355281  0.354182  0.331240
# spectral        0.341272  0.309406  0.319081

# %%
show_silhouette(Y_score)

# %% [markdown]
# Для датасета Y silhouette score показывает, что оптимальное число кластеров - 3. Эту оценку получают кластеры, полученные при работе всех алгоритмов. На практике также было показано, что все четыре алгоритма одинаково определяют три кластера, это же количество было определно как оптимальное при предварительном изучении данных.
#
# Разделение на три кластера получает наиболее высокие оценки и по модулярности, что еще раз подтверждает, что это оптимальное разделение.

# %% [markdown]
# ### Алгоритм Лювейна

# %% [markdown]
# Рассмотрим, как алгоритм Лювейна определяет оптимальное количество кластеров.

# %% [markdown]
# #### Для датасета X

# %%
X_partition = community_louvain.best_partition(X_graph)

# %%
pos = nx.spring_layout(X_graph)
cmap = cm.get_cmap('viridis', max(X_partition.values()) + 1)
nx.draw_networkx_nodes(X_graph, pos, X_partition.keys(), node_size=50,
                       cmap=cmap, node_color=list(X_partition.values()))
plt.show()

# %% [markdown]
# По визуализации графа видим, что Лювейн определил число кластеров равное 10. Сделаем более удобную визуализацию для рассмотрения нового разделения.

# %%
color_map = ['blue', 'orange', 'green', 'red', 'purple', 'brown', 'pink', 'gray', 'black', 'cyan']
for i in range(200):
        
        plt.scatter(X_2d[:,0][i] , X_2d[:,1][i], color=color_map[list(X_partition.values())[i]])

# %% [markdown]
# По графику видно, что новое разделение действительно имеет смысл, так как во многих случаях кластеры отделены друг от друга значителным расстоянием. Оценка по модулярности при таком разделении значительно лучше, чем при разделении на два кластера, которую мы определили как оптимальную для этого датасета.

# %%
get_set = lambda i, partition: {k for k,v in partition.items() if v == i}
all_sets = lambda partition: [get_set(i, partition) for i in range(max(partition.values())+1)]
nx.algorithms.community.quality.modularity(X_graph, all_sets(X_partition))
# Out:
# 0.814352371200446

# %% [markdown]
# #### Для датасета Y

# %% [markdown]
# Для датасета Y алгоритм Лювейна также определяет 3 кластера как оптимальные.

# %%
Y_partition = community_louvain.best_partition(Y_graph)

# %%
pos = nx.spring_layout(Y_graph)
# color the nodes according to their partition
cmap = cm.get_cmap('viridis', max(Y_partition.values()) + 1)
nx.draw_networkx_nodes(Y_graph, pos, Y_partition.keys(), node_size=40,
                       cmap=cmap, node_color=list(Y_partition.values()))
nx.draw_networkx_edges(Y_graph, pos, alpha=0.1)
plt.show()

# %%
color_map = ['blue', 'orange', 'green', 'red', 'purple', 'brown', 'pink', 'gray', 'olive', 'cyan']
for i in range(200):
        
        plt.scatter(Y_2d[:,0][i] , Y_2d[:,1][i], color=color_map[list(Y_partition.values())[i]])

# %%
nx.algorithms.community.quality.modularity(Y_graph, all_sets(Y_partition))
# Out:
# 0.384918265285757

# %% [markdown]
# ### Выводы
#
# В результате применения разных видов кластеризации однозначное разделение было найдено только для датасета Y - 3 кластера. Наше первоначальное предположение также было о разбиении на три кластера: кластеры характеризуются малым расстоянием в пределах одного кластера и большим между кластерами, что видно и из визуализации этих данных. Все алгоритмы верно относят элементы к кластерам.
#
# Для датасета X мы предварительно по визуализации определили, что оптимальное число кластеров - 2. В этом случае правильное разделение дают алгоритмы Single Linkage и Spectral Clustering. Однако оценки по модулярности и силуэту дали такому разбиению худшие оценки. Оценка силуэта наилучшая для количества кластеров от 8, причем алгоритм Лувейна дал 10 кластеров. Хотя визуально явно и определяются 2 крупных кластера, но возможно их разделение и на более мелкие кластеры - все зависит от задачи и наличии метаинформации за данными.
